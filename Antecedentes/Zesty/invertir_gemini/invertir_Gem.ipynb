# %%
import yfinance as yf
import pandas as pd
import numpy as np

# --- EL MEGA-UNIVERSO ZESTY (LISTADO COMPLETO DE ~400 ACTIVOS) ---
# Hemos expandido las categorías para incluir CADA ticker de tu lista.
zesty_mega_universe = {
    "Leveraged_Inverse": [
        "BITX", "UVIX", "SVIX", "ZIVB", "DWSH", "MSOX", "TARK", "SARK", "TSLQ", "DZZ", 
        "DGZ", "TMF", "AAPD", "AIBD", "AIBU", "AMZD", "CLDL", "QQAD", "CHAU", "CWEB", 
        "ERY", "ERX", "FAZ", "YANG", "YINN", "EURL", "DUST", "NUGT", "GGLS", "NAIL", 
        "JDST", "JNUG", "MIDU", "BRZU", "XXCH", "INDL", "MEXX", "NVDU", "UBOT", "SPDN", 
        "SPXS", "SPUU", "SPXL", "HIBS", "LABD", "LABU", "DRIP", "GUSH", "SOXS", "SOXL", 
        "TZA", "KORU", "TECS", "TECL", "OOTO", "TSLL", "WTID", "WTIU", "SHNY", "TBF", 
        "TBX", "DOG", "SETH", "SEF", "YXI", "MYY", "EFZ", "EUM", "PSQ", "REK", "RWM", 
        "SH", "SBB", "XPP", "UPV", "UBR", "EZJ", "TSLI", "TTT", "SDOW", "SMDD", "SRTY", 
        "SPXU", "EPV", "EWV", "TSLZ", "AAPX", "MSFX", "NVDX", "TSLT", "CRSH"
    ],
    "Equity_Individual_Stocks": [
        "MMM", "ACN", "ADBE", "AMD", "BABA", "GOOGL", "MO", "AMZN", "AAL", "AAPL", 
        "AMAT", "AIZ", "AXSM", "BIDU", "BDX", "BMRN", "BIO", "BKNG", "BWA", "BXP", 
        "BMY", "CHRW", "AI", "CZR", "CPB", "DAY", "CSCO", "KO", "CL", "CMA", "COST", 
        "CRSP", "CRWD", "CSX", "DVA", "DOCU", "DUK", "EQIX", "ETSY", "EXEL", "FMC", 
        "FOXA", "BEN", "FCX", "GME", "GNRC", "GILD", "GL", "HAS", "HSIC", "HRL", 
        "ITW", "INCY", "INTC", "IBM", "IVZ", "JAZZ", "JPM", "LMT", "MKTX", "MA", 
        "MTCH", "MCD", "MCK", "MDT", "META", "MSFT", "MRNA", "NFLX", "NWSA", "NIO", 
        "NCLH", "NVDA", "OMF", "ORCL", "PLTR", "PARA", "PH", "PAYC", "PYPL", "PEP", 
        "PFE", "PM", "PSX", "DOC", "PNW", "REG", "RHI", "CRM", "SAP", "SNAP", "SOLV", 
        "STLA", "TSM", "TPR", "TFX", "TSLA", "TMUS", "VZ", "DIS", "WYNN", "ZTS"
    ],
    "Fixed_Income_Cash": [
        "YEAR", "BAMU", "OPER", "FTEXX", "FUMB", "FLUD", "SGOV", "SHY", "TLT", "TLTW", 
        "IEI", "IEF", "IUSB", "SUSB", "EUSB", "FLOT", "IBTE", "HYG", "EMB", "MBB", 
        "IGSB", "JSCP", "JPST", "JMST", "TIPD", "BIL", "SPSB", "SPTS", "BIV", "VGIT", 
        "VMBS", "BSV", "VGSH", "VTEB", "VMSXX", "USFR", "PTEXX", "TBUX", "TUSI"
    ],
    "ETFs_Broad_Thematic": [
        "OEUR", "SDOG", "AMOMX", "ARKG", "ACWI", "VTI", "EWG", "KSA", "ARKQ", "GOVT", 
        "EWZ", "QAT", "MCHI", "EWY", "AOA", "AOM", "UAE", "EWP", "SPY", "EPHE", "EWQ", 
        "GREK", "PIN", "EIDO", "EIRL", "EIS", "EWI", "EWJ", "KWT", "EWM", "VEA", 
        "IEFA", "EEM", "NORW", "ENZL", "EWN", "EPU", "EPOL", "EWU", "AGG", "IVV", 
        "EWS", "EZA", "EWD", "EWL", "THD", "EWT", "QQQ", "TIP", "TUR", "VNM", "USML", 
        "MTUL", "IWML", "IWDL", "HDLB", "SMHB", "PFFL", "TTAI", "FTEC", "FDL", "FBT", 
        "FLAX", "FLAU", "FLBR", "FLCA", "FLCH", "FLEE", "FLEU", "FLGR", "FLHK", 
        "FLIN", "FLJP", "FLJH", "FLLA", "FLMX", "FLSA", "FLKR", "FLSW", "FLTW", 
        "FLGB", "ASEA", "GNOM", "BOTZ", "SRET", "MLPA", "COLO", "VNAM", "SDIV", 
        "EWRI", "DJD", "PRF", "PEY", "KBWD", "SPHD", "RDIV", "PHO", "IBB", "HDV", 
        "DVYE", "USXF", "ESGD", "ESGE", "ESGU", "IGM", "IDNA", "ICLN", "IXN", "EWZS", 
        "TCHI", "SMIN", "SCJ", "EWJV", "EWW", "EWUS", "SUSA", "USMV", "SIZE", "SMMV", 
        "SMLF", "VLUE", "URTH", "PFF", "IWM", "IJS", "SOXX", "SHV", "IYW", "JEPQ", 
        "KBA", "KURE", "KALL", "QCLN", "PULT", "SWISX", "SCHD", "SCHH", "SCHA", "TAN", 
        "BIL", "RWR", "KOMP", "SPYD", "LGLV", "TWOK", "MMTM", "VFIAX", "VTMGX", "VIG", 
        "VUG", "VYM", "VGT", "VYMI", "VNQ", "VOO", "VXUS", "DGRW", "EPS", "DLN", "DTD", "USSG"
    ]
}

# Consolidar todos los tickers únicos
full_ticker_list = sorted(list(set([t for sublist in zesty_mega_universe.values() for t in sublist])))

print(f"🚀 [Zesty Engine] Universo total detectado: {len(full_ticker_list)} activos.")
print(f"📊 Categorías: {list(zesty_mega_universe.keys())}")
# Out:
# 🚀 [Zesty Engine] Universo total detectado: 392 activos.
# 📊 Categorías: ['Leveraged_Inverse', 'Equity_Individual_Stocks', 'Fixed_Income_Cash', 'ETFs_Broad_Thematic']

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime

# --- RE-DEFINICIÓN DE SEGURIDAD (Para evitar NameError) ---
zesty_mega_universe = {
    "Leveraged_Inverse": [
        "BITX", "UVIX", "SVIX", "ZIVB", "DWSH", "MSOX", "TARK", "SARK", "TSLQ", "DZZ", 
        "DGZ", "TMF", "AAPD", "AIBD", "AIBU", "AMZD", "CLDL", "QQAD", "CHAU", "CWEB", 
        "ERY", "ERX", "FAZ", "YANG", "YINN", "EURL", "DUST", "NUGT", "GGLS", "NAIL", 
        "JDST", "JNUG", "MIDU", "BRZU", "XXCH", "INDL", "MEXX", "NVDU", "UBOT", "SPDN", 
        "SPXS", "SPUU", "SPXL", "HIBS", "LABD", "LABU", "DRIP", "GUSH", "SOXS", "SOXL", 
        "TZA", "KORU", "TECS", "TECL", "OOTO", "TSLL", "WTID", "WTIU", "SHNY", "TBF", 
        "TBX", "DOG", "SETH", "SEF", "YXI", "MYY", "EFZ", "EUM", "PSQ", "REK", "RWM", 
        "SH", "SBB", "XPP", "UPV", "UBR", "EZJ", "TSLI", "TTT", "SDOW", "SMDD", "SRTY", 
        "SPXU", "EPV", "EWV", "TSLZ", "AAPX", "MSFX", "NVDX", "TSLT", "CRSH"
    ],
    "Equity_Individual_Stocks": [
        "MMM", "ACN", "ADBE", "AMD", "BABA", "GOOGL", "MO", "AMZN", "AAL", "AAPL", 
        "AMAT", "AIZ", "AXSM", "BIDU", "BDX", "BMRN", "BIO", "BKNG", "BWA", "BXP", 
        "BMY", "CHRW", "AI", "CZR", "CPB", "DAY", "CSCO", "KO", "CL", "CMA", "COST", 
        "CRSP", "CRWD", "CSX", "DVA", "DOCU", "DUK", "EQIX", "ETSY", "EXEL", "FMC", 
        "FOXA", "BEN", "FCX", "GME", "GNRC", "GILD", "GL", "HAS", "HSIC", "HRL", 
        "ITW", "INCY", "INTC", "IBM", "IVZ", "JAZZ", "JPM", "LMT", "MKTX", "MA", 
        "MTCH", "MCD", "MCK", "MDT", "META", "MSFT", "MRNA", "NFLX", "NWSA", "NIO", 
        "NCLH", "NVDA", "OMF", "ORCL", "PLTR", "PARA", "PH", "PAYC", "PYPL", "PEP", 
        "PFE", "PM", "PSX", "DOC", "PNW", "REG", "RHI", "CRM", "SAP", "SNAP", "SOLV", 
        "STLA", "TSM", "TPR", "TFX", "TSLA", "TMUS", "VZ", "DIS", "WYNN", "ZTS"
    ],
    "Fixed_Income_Cash": [
        "YEAR", "BAMU", "OPER", "FTEXX", "FUMB", "FLUD", "SGOV", "SHY", "TLT", "TLTW", 
        "IEI", "IEF", "IUSB", "SUSB", "EUSB", "FLOT", "IBTE", "HYG", "EMB", "MBB", 
        "IGSB", "JSCP", "JPST", "JMST", "TIPD", "BIL", "SPSB", "SPTS", "BIV", "VGIT", 
        "VMBS", "BSV", "VGSH", "VTEB", "VMSXX", "USFR", "PTEXX", "TBUX", "TUSI"
    ],
    "ETFs_Broad_Thematic": [
        "OEUR", "SDOG", "AMOMX", "ARKG", "ACWI", "VTI", "EWG", "KSA", "ARKQ", "GOVT", 
        "EWZ", "QAT", "MCHI", "EWY", "AOA", "AOM", "UAE", "EWP", "SPY", "EPHE", "EWQ", 
        "GREK", "PIN", "EIDO", "EIRL", "EIS", "EWI", "EWJ", "KWT", "EWM", "VEA", 
        "IEFA", "EEM", "NORW", "ENZL", "EWN", "EPU", "EPOL", "EWU", "AGG", "IVV", 
        "EWS", "EZA", "EWD", "EWL", "THD", "EWT", "QQQ", "TIP", "TUR", "VNM", "USML", 
        "MTUL", "IWML", "IWDL", "HDLB", "SMHB", "PFFL", "TTAI", "FTEC", "FDL", "FBT", 
        "FLAX", "FLAU", "FLBR", "FLCA", "FLCH", "FLEE", "FLEU", "FLGR", "FLHK", 
        "FLIN", "FLJP", "FLJH", "FLLA", "FLMX", "FLSA", "FLKR", "FLSW", "FLTW", 
        "FLGB", "ASEA", "GNOM", "BOTZ", "SRET", "MLPA", "COLO", "VNAM", "SDIV", 
        "EWRI", "DJD", "PRF", "PEY", "KBWD", "SPHD", "RDIV", "PHO", "IBB", "HDV", 
        "DVYE", "USXF", "ESGD", "ESGE", "ESGU", "IGM", "IDNA", "ICLN", "IXN", "EWZS", 
        "TCHI", "SMIN", "SCJ", "EWJV", "EWW", "EWUS", "SUSA", "USMV", "SIZE", "SMMV", 
        "SMLF", "VLUE", "URTH", "PFF", "IWM", "IJS", "SOXX", "SHV", "IYW", "JEPQ", 
        "KBA", "KURE", "KALL", "QCLN", "PULT", "SWISX", "SCHD", "SCHH", "SCHA", "TAN", 
        "BIL", "RWR", "KOMP", "SPYD", "LGLV", "TWOK", "MMTM", "VFIAX", "VTMGX", "VIG", 
        "VUG", "VYM", "VGT", "VYMI", "VNQ", "VOO", "VXUS", "DGRW", "EPS", "DLN", "DTD", "USSG"
    ]
}

full_ticker_list = sorted(list(set([t for sublist in zesty_mega_universe.values() for t in sublist])))

# --- FUNCIÓN DE DESCARGA Y PROCESAMIENTO ---
def get_zesty_data(tickers, years=2):
    end_date = datetime.now()
    start_date = end_date - pd.Timedelta(days=years*365)
    
    print(f"⏳ Iniciando descarga masiva de {len(tickers)} activos para el portafolio Zesty...")
    
    # Descarga directa de Adjusted Close
    data = yf.download(tickers, start=start_date, end=end_date, interval="1d")['Adj Close']
    
    # Limpieza: Eliminamos columnas que tengan más del 50% de datos vacíos (activos muy nuevos)
    data = data.dropna(thresh=len(data)*0.5, axis=1)
    
    # Rellenamos huecos (ffill) para consistencia en el cálculo de retornos
    data = data.ffill()
    
    return data

# 1. Descargar precios
df_prices = get_zesty_data(full_ticker_list)

# 2. Calcular Retornos Logarítmicos (Crucial para análisis cuantitativo)
df_returns = np.log(df_prices / df_prices.shift(1)).dropna()

print(f"\n✅ Bloque 2 Completado.")
print(f"📈 Activos procesados con éxito: {df_prices.shape[1]}")
print(f"📅 Rango de datos: {df_prices.index[0].date()} a {df_prices.index[-1].date()}")
# Out:
# ⏳ Iniciando descarga masiva de 392 activos para el portafolio Zesty...
# [**************        30%                       ]  119 of 392 completedHTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: QQAD"}}}
# [*****************     35%                       ]  138 of 392 completed$QQAD: possibly delisted; no timezone found
# [**********************88%*****************      ]  345 of 392 completedHTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: PARA"}}}
# [**********************88%*****************      ]  346 of 392 completed$EWRI: possibly delisted; no timezone found
# [**********************93%********************   ]  366 of 392 completed$PARA: possibly delisted; no timezone found
# ...

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime

# --- 1. RE-DEFINICIÓN DEL UNIVERSO (Carga de seguridad) ---
zesty_mega_universe = {
    "Leveraged_Inverse": ["BITX", "UVIX", "SVIX", "ZIVB", "DWSH", "MSOX", "TARK", "SARK", "TSLQ", "DZZ", "DGZ", "TMF", "AAPD", "AIBD", "AIBU", "AMZD", "CLDL", "QQAD", "CHAU", "CWEB", "ERY", "ERX", "FAZ", "YANG", "YINN", "EURL", "DUST", "NUGT", "GGLS", "NAIL", "JDST", "JNUG", "MIDU", "BRZU", "XXCH", "INDL", "MEXX", "NVDU", "UBOT", "SPDN", "SPXS", "SPUU", "SPXL", "HIBS", "LABD", "LABU", "DRIP", "GUSH", "SOXS", "SOXL", "TZA", "KORU", "TECS", "TECL", "OOTO", "TSLL", "WTID", "WTIU", "SHNY", "TBF", "TBX", "DOG", "SETH", "SEF", "YXI", "MYY", "EFZ", "EUM", "PSQ", "REK", "RWM", "SH", "SBB", "XPP", "UPV", "UBR", "EZJ", "TSLI", "TTT", "SDOW", "SMDD", "SRTY", "SPXU", "EPV", "EWV", "TSLZ", "AAPX", "MSFX", "NVDX", "TSLT", "CRSH"],
    "Equity_Individual_Stocks": ["MMM", "ACN", "ADBE", "AMD", "BABA", "GOOGL", "MO", "AMZN", "AAL", "AAPL", "AMAT", "AIZ", "AXSM", "BIDU", "BDX", "BMRN", "BIO", "BKNG", "BWA", "BXP", "BMY", "CHRW", "AI", "CZR", "CPB", "DAY", "CSCO", "KO", "CL", "CMA", "COST", "CRSP", "CRWD", "CSX", "DVA", "DOCU", "DUK", "EQIX", "ETSY", "EXEL", "FMC", "FOXA", "BEN", "FCX", "GME", "GNRC", "GILD", "GL", "HAS", "HSIC", "HRL", "ITW", "INCY", "INTC", "IBM", "IVZ", "JAZZ", "JPM", "LMT", "MKTX", "MA", "MTCH", "MCD", "MCK", "MDT", "META", "MSFT", "MRNA", "NFLX", "NWSA", "NIO", "NCLH", "NVDA", "OMF", "ORCL", "PLTR", "PARA", "PH", "PAYC", "PYPL", "PEP", "PFE", "PM", "PSX", "DOC", "PNW", "REG", "RHI", "CRM", "SAP", "SNAP", "SOLV", "STLA", "TSM", "TPR", "TFX", "TSLA", "TMUS", "VZ", "DIS", "WYNN", "ZTS"],
    "Fixed_Income_Cash": ["YEAR", "BAMU", "OPER", "FTEXX", "FUMB", "FLUD", "SGOV", "SHY", "TLT", "TLTW", "IEI", "IEF", "IUSB", "SUSB", "EUSB", "FLOT", "IBTE", "HYG", "EMB", "MBB", "IGSB", "JSCP", "JPST", "JMST", "TIPD", "BIL", "SPSB", "SPTS", "BIV", "VGIT", "VMBS", "BSV", "VGSH", "VTEB", "VMSXX", "USFR", "PTEXX", "TBUX", "TUSI"],
    "ETFs_Broad_Thematic": ["OEUR", "SDOG", "AMOMX", "ARKG", "ACWI", "VTI", "EWG", "KSA", "ARKQ", "GOVT", "EWZ", "QAT", "MCHI", "EWY", "AOA", "AOM", "UAE", "EWP", "SPY", "EPHE", "EWQ", "GREK", "PIN", "EIDO", "EIRL", "EIS", "EWI", "EWJ", "KWT", "EWM", "VEA", "IEFA", "EEM", "NORW", "ENZL", "EWN", "EPU", "EPOL", "EWU", "AGG", "IVV", "EWS", "EZA", "EWD", "EWL", "THD", "EWT", "QQQ", "TIP", "TUR", "VNM", "USML", "MTUL", "IWML", "IWDL", "HDLB", "SMHB", "PFFL", "TTAI", "FTEC", "FDL", "FBT", "FLAX", "FLAU", "FLBR", "FLCA", "FLCH", "FLEE", "FLEU", "FLGR", "FLHK", "FLIN", "FLJP", "FLJH", "FLLA", "FLMX", "FLSA", "FLKR", "FLSW", "FLTW", "FLGB", "ASEA", "GNOM", "BOTZ", "SRET", "MLPA", "COLO", "VNAM", "SDIV", "EWRI", "DJD", "PRF", "PEY", "KBWD", "SPHD", "RDIV", "PHO", "IBB", "HDV", "DVYE", "USXF", "ESGD", "ESGE", "ESGU", "IGM", "IDNA", "ICLN", "IXN", "EWZS", "TCHI", "SMIN", "SCJ", "EWJV", "EWW", "EWUS", "SUSA", "USMV", "SIZE", "SMMV", "SMLF", "VLUE", "URTH", "PFF", "IWM", "IJS", "SOXX", "SHV", "IYW", "JEPQ", "KBA", "KURE", "KALL", "QCLN", "PULT", "SWISX", "SCHD", "SCHH", "SCHA", "TAN", "BIL", "RWR", "KOMP", "SPYD", "LGLV", "TWOK", "MMTM", "VFIAX", "VTMGX", "VIG", "VUG", "VYM", "VGT", "VYMI", "VNQ", "VOO", "VXUS", "DGRW", "EPS", "DLN", "DTD", "USSG"]
}

full_requested = sorted(list(set([t for sublist in zesty_mega_universe.values() for t in sublist])))

# --- 2. DESCARGA Y FILTRADO ---
years = 2
end_date = datetime.now()
start_date = end_date - pd.Timedelta(days=years*365)

print(f"📡 Solicitando {len(full_requested)} activos...")
data_raw = yf.download(full_requested, start=start_date, end=end_date, interval="1d", progress=False)['Adj Close']

# Filtro de historia (50% de datos)
data_clean = data_raw.dropna(thresh=len(data_raw)*0.5, axis=1)

# --- 3. ANÁLISIS DE FALLAS (EL SAPEO) ---
total_solicitados = set(full_requested)
total_obtenidos_raw = set(data_raw.columns)
total_finales = set(data_clean.columns)

# Fallas críticas: Yahoo no devolvió absolutamente nada
fallas_tickers = total_solicitados - total_obtenidos_raw

# Fallas por historia: El ticker existe, pero tiene pocos datos (ETFs muy nuevos)
fallas_historia = total_obtenidos_raw - total_finales

print("-" * 50)
print(f"📊 RESUMEN TÉCNICO:")
print(f"✅ Activos Listos: {len(total_finales)}")
print(f"❌ Fallas Críticas (No encontrados): {len(fallas_tickers)}")
print(f"⏳ Fallas Historia (Muy nuevos < 50% data): {len(fallas_historia)}")
print("-" * 50)

if fallas_tickers:
    print(f"🚫 TICKERS NO ENCONTRADOS (Revisar sintaxis o delisting):")
    print(sorted(list(fallas_tickers)))

if fallas_historia:
    print(f"\n⚠️ TICKERS CON DATA INSUFICIENTE (Nacieron hace poco):")
    print(sorted(list(fallas_historia)))
# Out:
# 📡 Solicitando 392 activos...
# $QQAD: possibly delisted; no timezone found
# $PARA: possibly delisted; no timezone found
# $EWRI: possibly delisted; no timezone found
# $TWOK: possibly delisted; no price data found  (1d 2024-04-03 20:51:49.842210 -> 2026-04-03 20:51:49.842210)
#
# 4 Failed downloads:
# ['QQAD', 'PARA', 'EWRI']: possibly delisted; no timezone found
# ['TWOK']: possibly delisted; no price data found  (1d 2024-04-03 20:51:49.842210 -> 2026-04-03 20:51:49.842210)
# --------------------------------------------------
# 📊 RESUMEN TÉCNICO:
# ✅ Activos Listos: 0
# ❌ Fallas Críticas (No encontrados): 388
# ⏳ Fallas Historia (Muy nuevos < 50% data): 4
# --------------------------------------------------
# 🚫 TICKERS NO ENCONTRADOS (Revisar sintaxis o delisting):
# ...
